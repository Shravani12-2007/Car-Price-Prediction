# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('final_cleaned_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        679 non-null    object
#  1   company     679 non-null    object
#  2   year        679 non-null    int64
#  3   Price       679 non-null    int64
#  4   kms_driven  679 non-null    int64
#  5   fuel_type   679 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 32.0+ KB

# %%
# Divide dataset into X and y

X = df[['name', 'company', 'year', 'kms_driven', 'fuel_type']]
y = df[['Price']]

# %%
X["name"].unique()
# Out:
# array(['Santro Xing XO eRLX Euro III', 'Jeep CL550 MDI',
#        'Grand i10 Magna 1.2 Kappa VTVT', 'EcoSport Titanium 1.5L TDCi',
#        'Figo', 'Eon', 'EcoSport Ambiente 1.5L TDCi', 'Alto K10 VXi AMT',
#        'Fabia Classic 1.2 MPI', 'Stingray VXi', 'Elite i20 Magna 1.2',
#        'Scorpio SLE BS IV', 'Q7', 'Scorpio S10', 'Alto 800',
#        'Alto 800 Vxi', 'i20 Sportz 1.2', 'Alto 800 Lx',
#        'Vitara Brezza ZDi', 'Alto LX', 'Bolero DI', 'Swift Dzire ZDi',
#        'Scorpio S10 4WD', 'Swift Vdi BSIII', 'Wagon R VXi BS III',
#        'Wagon R VXi Minor', 'Innova 2.0 G 8 STR BS IV', 'Lodgy 85 PS RXL',
#        'Yeti Ambition 2.0 TDI CR 4x2', 'Baleno Delta 1.2',
#        'Duster 110 PS RxZ Diesel Plus', 'Duster 85 PS RxE Diesel',
#        'City 1.5 S MT', 'Dzire', 'Amaze', 'Amaze 1.5 SX i DTEC', 'City',
#        'Redi GO S', 'SX4 ZXI MT', 'Swift VXi 1.2 ABS BS IV',
#        'City ZX CVT', 'Wagon R LX BS IV', 'Indigo eCS LS CR4 BS IV',
#        'Polo Highline Exquisite P', 'Spark LS 1.0',
#        'Duster 110PS Diesel RxZ', 'Fabia 1.2L Diesel Ambiente', 'Duster',
#        'Scorpio S4', 'Scorpio VLX 2WD BS IV', 'Quanto C8', 'EcoSport',
#        'Brio', 'i20 Magna', 'Corolla Altis Diesel D4DG',
#        'Verna Transform SX VTVT', 'Corolla Altis Petrol Ltd',
#        'City 1.5 EXi New', 'Fabia 1.2L Diesel Elegance', '3 Series 320i',
#        'A Star Lxi', 'Etios GD', 'Figo Diesel EXI Option',
#        'Swift Dzire VXi 1.2 BS IV', 'Beat LT Diesel',
#        'XUV500 W8 AWD 2013', 'i10 Magna 1.2', 'Verna Fluidic New',
#        'Swift VXi 1.2 BS IV', 'Ertiga ZXI Plus', 'Ertiga Vxi',
#        'Ertiga VDi', 'Alto LXi BS III', 'Grand i10 Asta 1.1 CRDi',
#        'Amaze 1.2 S i VTEC', 'i20 Asta 1.4 CRDI 6 Speed',
#        'Figo Diesel EXI', 'Eeco 5 STR WITH AC HTR', 'Ertiga ZXi',
#        'Esteem LXi BS III', 'Ritz VXI', 'Ritz LDi', 'Dzire VDI',
#        'Etios Liva G', 'i20 Sportz 1.4 CRDI', 'Spark', 'Micra XV',
#        'Swift', 'Amaze 1.5 S i DTEC', 'Beat', 'City 1.5 V MT',
#        'EcoSport Trend 1.5L TDCi', 'i20 Asta 1.2', 'Indica V2 eLS',
#        'Motors Ambassador', 'Corolla Altis 1.8 GL', 'Corolla Altis 1.8 J',
#        'Innova 2.5 GX BS IV 7 STR', 'Jetta Highline TDI AT',
#        'Polo Comfortline 1.2L P', 'Polo', 'Sunny', 'Elite i20', 'Kwid',
#        'Scorpio VLX Airbag', 'Alto 800 Lxi', 'Spark LT 1.0',
#        'Redi GO T O', 'Swift RS VDI', 'Punto Emotion 1.2',
#        'i10 Sportz 1.2', 'Beat LT Opt Diesel', 'Beat LS Diesel',
#        'Indigo CS', 'Swift VDi', 'Eon Era Plus', 'XUV500', 'Fiesta',
#        'Wagon R', 'i20', 'Indigo eCS LX TDI BS III',
#        'Fluidic Verna 1.6 CRDi SX', 'Petra ELX 1.2 PS', 'Santro Xing XS',
#        'Ciaz VXi Plus', 'Zen VX', 'Creta 1.6 SX Plus Petrol',
#        'Scorpio SLX', 'Innova 2.5 G BS III 8 STR', 'Wagon R LXI BS IV',
#        'Nano Cx BSIV', 'Alto Std BS IV', 'Wagon R LXi BS III',
#        'Swift VXI BSIII', 'Sumo Victa EX 10 by 7 Str BSIII',
#        'Passat Diesel Comfortline AT', 'Scala RxL Diesel Travelogue',
#        'Grand i10 Sportz O 1.2 Kappa VTVT', 'i20 Active 1.2 SX',
#        'Xylo E4', 'Jeep MM 550 XDB', 'Bolero SLE BS IV',
#        'Motors Force One LX ABS 7 STR', 'SX4', 'Etios', 'City ZX VTEC',
#        'Wagon R LX BS III', 'City VX O MT Diesel', 'Thar CRDe 4x4 AC',
#        'A4 1.8 TFSI Multitronic Premium Plus', 'Kwid RXT',
#        'Aria Pleasure 4X2', 'GO T O', 'Jazz VX MT',
#        'i20 Active 1.4L SX O', 'Ciaz ZXI Plus', 'Tavera Neo',
#        'Eon Sportz', 'Sumo Gold Select Variant', 'Wagon R 1.0',
#        'Esteem VXi BS III', 'Enjoy 1.4 LS 8 STR', 'Wagon R 1.0 VXi',
#        'Terrano XL D Plus', 'Duster 85 PS RxL Diesel', 'Dzire ZXI',
#        'Kwid RXT Opt', '800 Std', 'Kwid 1.0 RXT AMT', 'Scala RxL Diesel',
#        'Grand i10 Asta 1.2 Kappa VTVT O', 'Beat LS Petrol', 'Accent GLX',
#        'TUV300 T4 Plus', 'Indica V2 Xeta e GLE', 'Indigo CS LS DiCOR',
#        'Scorpio VLX Special Edition BS III', 'Accord',
#        'EcoSport Titanium 1.5 TDCi', 'Ertiga', 'Scorpio 2.6 CRDe',
#        'Mobilio', 'Corolla Altis', 'Laura', 'Verna Fluidic',
#        'Vitara Brezza', 'Scorpio', 'Manza Aura Quadrajet',
#        'Sail UVA Petrol LT ABS', 'Verna Fluidic 1.6 VTVT SX',
#        'Elantra SX', 'Scorpio VLX 4WD Airbag', 'KUV100 K8 D 6 STR',
#        'Grand i10', 'i10', 'i20 Active', 'Redi GO', 'Etios Liva',
#        'Accent', 'Verna', 'i10 Sportz', 'Bolero Power Plus SLE',
#        'City 1.5 V MT Exclusive', 'Spark LT 1.0 Airbag',
#        'Indigo eCS VX CR4 BS IV', 'Rapid Elegance 1.6 TDI CR MT',
#        'Vista Quadrajet VX', 'Alto K10 VXi AT', 'Zen LXi BS III',
#        'Swift Dzire Tour LDi', 'City ZX EXi', 'Beat Diesel',
#        'Verna 1.4 VTVT', 'Innova 2.5 E MS 7 STR BS IV', '800 Std – Befo',
#        'Elite i20 Asta 1.4 CRDI', 'Versa DX2 8 SEATER BSIII',
#        'Indigo LX TDI BS III', 'Vento Konekt Diesel Highline',
#        'C Class 200 CDI Classic', 'Santro Xing GLS',
#        'Omni Limited Edition', 'Sonata Transform 2.4 GDi MT',
#        'Elite i20 Sportz 1.2', 'Jazz S MT',
#        'Grand i10 Sportz 1.2 Kappa VTVT', 'Zen LXi BSII',
#        'Scorpio W Turbo 2.6DX 9 Seater', 'Alto K10 VXi',
#        'Grand i10 Asta 1.2 Kappa VTVT', 'XUV500 W8', 'i20 Magna O 1.2',
#        'Duster 85 PS RxL Explore LE', 'Brio V MT',
#        'Ikon 1.3 CLXi NXt Finesse', 'Fortuner 3.0 4x4 MT',
#        'Manza ELAN Quadrajet', 'Indigo LS', 'i20 Magna 1.2',
#        'Vento Highline Plus 1.5 Diesel AT', 'Amaze 1.5 E i DTEC',
#        'Verna 1.6 EX VTVT', 'Superb 1.8 TFSI AT', 'Bolero DI BSII',
#        'Figo Duratorq Diesel Titanium 1.4', 'Wagon R VXI BS IV',
#        'Logan Diesel 1.5 DLS', 'Nano GenX XMA', 'City SV',
#        'Figo Petrol LXI', 'i10 Magna 1.2 Kappa2', 'Corolla H2',
#        'Swift Dzire Tour VXi', 'Indigo CS eLS BS IV',
#        'Xcent Base 1.1 CRDi', 'Accent Executive Edition',
#        'Zest XE 75 PS Diesel', 'Dzire LDI', 'Sumo Gold LX BS IV',
#        'Corolla Altis GL Petrol', 'Eeco 7 STR', 'XUV500 W6',
#        'Tigor Revotron XZ', '800', 'Mobilio S i DTEC', 'Verna 1.6 CRDI E',
#        'Omni Select Variant', 'Indica', 'Santro Xing', 'Zen Estilo',
#        'Brio VX AT', 'Zen Estilo LXI Green CNG', 'Wagon R Select Variant',
#        'Nano Lx BSIV', 'Eon Magna Plus', 'Ritz GENUS VXI',
#        'Grand i10 Magna AT 1.2 Kappa VTVT', 'Eon D Lite Plus',
#        'Amaze 1.2 VX i VTEC', 'Estilo VXi ABS BS IV',
#        'Vitara Brezza LDi O', 'Scorpio Vlx BSIV', 'Lancer 1.8 LXi',
#        '800 AC', 'Alto 800 LXI CNG O', 'Fiesta SXi 1.6 ABS', 'Ritz VDi',
#        'Estilo LX BS IV', 'Alto', 'Baleno Sigma 1.2',
#        'Verna 1.6 SX VTVT AT', 'Swift GLAM', 'Getz Prime 1.3 GVS',
#        'Santro', 'Getz Prime 1.3 GLX', 'Beat PS Diesel',
#        'EcoSport Trend 1.5 Ti VCT', 'Indica V2 DLG', 'City 1.5 V AT',
#        'Nano', 'Cruze LTZ AT', 'Swift Dzire VDi', 'Alto K10 LXi CNG',
#        'Accent GLE', 'Motors One SUV', 'Spark 1.0 LT', 'Etios Liva GD',
#        'Duster 85PS Diesel RxL Optional with Nav', 'Enjoy',
#        '5 Series 530i', 'Cruze LTZ', 'Wrangler Unlimited 4x4 Diesel',
#        'Verna VGT CRDi SX ABS', 'Omni', 'Celerio VDi',
#        'Zest Quadrajet 1.3', 'Indigo CS eLX BS IV', 'i10 Era',
#        'Indigo eCS LX CR4 BS IV', 'Indigo Marina LS', 'Xcent SX 1.2',
#        'Nano LX Special Edition', 'Duster 110 PS RxZ Diesel',
#        'Wagon R AX BSIV', 'Alto K10 New', 'Xylo E8',
#        'Manza Aqua Quadrajet', 'Kwid 1.0', 'Venture EX 8 STR',
#        'Swift Dzire Tour LXi', 'Octavia Classic 1.9 TDI MT',
#        'Omni LPG BS IV', 'Sumo Gold EX BS IV', 'Verna 1.6 CRDI SX',
#        'Scorpio SLX 2.6 Turbo 8 Str', 'Ikon 1.6 Nxt',
#        'Innova 2.5 V 7 STR', 'Sunny XL', 'Swift VDi BS IV',
#        'Innova 2.0 G4', 'Swift VDi ABS', 'Elite i20 Asta 1.2',
#        'Polo Trendline 1.5L D', 'Etios Liva Diesel', 'Ciaz ZXi Plus RS',
#        'Elantra 1.8 S', 'EcoSport Trend 1.5L Ti VCT', 'Indica eV2 LS',
#        'Swift ZXi 1.2 BS IV', 'S Cross Sigma 1.3', 'Ertiga LDi',
#        'Vento Comfortline Petrol', 'KUV100', 'Swift Dzire Tour VDi',
#        'Scorpio 2.6 SLX', 'Omni 8 STR BS III',
#        'Jetta Comfortline 1.9 TDI AT', 'Corolla Altis VL AT Petrol',
#        'Beat LT Petrol', 'Vento Comfortline Diesel', 'Indigo CS GLS',
#        'Figo Petrol Titanium', 'City ZX GXi', 'Wagon R Duo Lxi',
#        'Zen LX BSII', 'Duster RxL Petrol', 'Baleno Zeta 1.2',
#        'WR V S MT Petrol', 'Duster 110 PS RxL Diesel',
#        'Scorpio LX BS III', 'SX4 Celebration Diesel',
#        'Santro AE GLS Audio', 'Xylo D2 BS IV', 'Getz GLE',
#        'Santro Xing XL AT eRLX Euro III', 'Santro Xing XL eRLX Euro III',
#        'Indica V2 DLS BS III', 'City 1.5 E MT', 'Micra XL',
#        'City 1.5 S Inspire', 'Indica eV2 eXeta eGLX',
#        'Omni E 8 STR BS IV', 'Swift LDi', 'Verna 1.6 CRDI SX Plus AT',
#        'Tavera LS B3 10 Seats BSII', 'Tiago Revotron XM',
#        'Tiago Revotorq XZ', 'Motors Ambassador Classic Mark 4 – Befo',
#        'Fusion 1.4 TDCi Diesel', 'Linea Emotion 1.4 L T Jet Petrol',
#        'Ikon 1.3 Flair Josh 100', 'Indica V2 LS', 'Xylo D2', 'Corolla',
#        'Eon Magna', 'Sumo Grande MKII GX', 'Polo Highline1.2L P',
#        'Tiago Revotron XZ', 'Indigo eCS', 'Xylo E8 BS IV',
#        'Sumo Gold FX BSIII', 'Creta', 'Bolt XM Petrol', 'Ritz',
#        'i20 Asta', 'Swift Select Variant', 'Indica V2 DLX BS III',
#        'Scorpio VLX 2.2 mHawk Airbag BSIV', 'Innova 2.5 E 8 STR',
#        'KUV100 K8 6 STR', 'Go Plus', 'Indica V2', 'Santro Xing GL',
#        'Innova 2.5 Z Diesel 7 Seater', 'Alto AX', 'Logan',
#        '800 Std BS III', 'Sail 1.2 LS', 'Manza', 'Etios G', 'Qualis',
#        'Quanto C4', 'Swift Dzire', 'i20 Select Variant', 'City VX Petrol',
#        'Getz', 'C Class 200 K MT', 'Fabia', 'Ritz VXI ABS',
#        'Indica V2 DLE BS III', 'Zest XM Diesel'], dtype=object)

# %%
X["company"].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Tata', 'Volkswagen', 'Chevrolet',
#        'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force', 'Mercedes',
#        'Mitsubishi', 'Jeep'], dtype=object)

# %%
X["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
#Lets build pipeline

#Create obj for OneHotEncoder
ohe = OneHotEncoder()
ohe.fit(X[['company', 'name', 'fuel_type']])
# ohe.categories_
ct = make_column_transformer((OneHotEncoder(categories = ohe.categories_), ['company', 'name', 'fuel_type']), remainder = 'passthrough')

model = LinearRegression()

# pass input as ct to model
#train to pipeline
pipe = make_pipeline(ct, model)
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jeep', 'Mahindra', 'Maruti',
#        'Mercedes', 'Mitsubishi', 'Nissan', 'Renault', 'Skoda', 'Tata',
#        'Toyota', 'Volkswagen'], dtype=object)...
#        'i10 Magna 1.2', 'i10 Magna 1.2 Kappa2', 'i10 Sportz',
#        'i10 Sportz 1.2', 'i20', 'i20 Active', 'i20 Active 1.2 SX',
#        'i20 Active 1.4L SX O', 'i20 Asta', 'i20 Asta 1.2',
#        'i20 Asta 1.4 CRDI 6 Speed', 'i20 Magna', 'i20 Magna 1.2',
#        'i20 Magna O 1.2', 'i20 Select Variant', 'i20 Sportz 1.2',
#        'i20 Sportz 1.4 CRDI'], dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
# #Lets divide data into train and test
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import r2_score
# # scores = []

# # # To get the best accuracy we need to change random_score value to get best accuracy score. using for loop we can achieve it.

# # for i in range(0, 101):
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 8)
# #Lets train pipe
# pipe.fit(X_train, y_train)
# #Lets test and find accuracy

#     # scores.append(score)

# y_pred = pipe.predict(X_test)
# y_pred
# y_pred = pd.DataFrame(data = y_pred, columns = ['Prediction'])
# result = pd.concat([y_test.reset_index(drop = True), y_pred], axis = 1)
# score = r2_score(result['Price'], result['Prediction'])
# score
#Lets divide data into train and test
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
scores = []

# To get the best accuracy we need to change random_score value to get best accuracy score. using for loop we can achieve it.

for i in range(0, 101):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = i)
    #Lets train pipe
    pipe.fit(X_train, y_train)
    #Lets test and find accuracy
    y_pred = pipe.predict(X_test)
    y_pred = pd.DataFrame(data = y_pred, columns = ['Prediction'])
    result = pd.concat([y_test.reset_index(drop = True), y_pred], axis = 1)
    score = r2_score(result['Price'], result['Prediction'])
    scores.append(score)

scores
# Out:
# [0.5530050865887798,
#  0.47339051777017116,
#  0.4889403678141556,
#  0.5814551006946982,
#  0.47702931407831906,
#  0.4876721887336253,
#  0.4668295818298601,
#  0.588359255786874,
#  0.46587601449434857,
#  0.4545509325265651,
#  0.4627874553268332,
#  0.48658383870538624,
#  0.6046170814749339,
#  0.5369083417864631,
#  0.5587310218842991,
#  0.6608277043308461,
#  0.4417510326532834,
#  0.603180624534547,
#  0.5552409644199058,
#  0.47118669674540536,
#  0.47256417917509486,
#  0.647097201124303,
#  0.4164590045763541,
#  0.317839600499637,
#  0.6162898632516203,
#  0.48746906001985923,
#  0.4832153118719673,
#  0.637955874461279,
#  0.5689933306239708,
#  0.6467494770359195,
#  0.5140259621406467,
#  0.5129767681229522,
#  0.37320664392870195,
#  0.35331640310377743,
#  0.7232676944522258,
#  0.2656641091985942,
#  0.436885436960913,
#  0.43310097218145927,
#  0.4875540671281303,
#  0.6425490323403514,
#  0.5603159881769659,
#  0.4861457936499346,
#  0.5456867791973439,
#  0.3952363824040004,
#  0.6260467013512134,
#  0.540378070339796,
#  0.6535806732583884,
#  0.6452043477324323,
#  0.515221601757311,
#  0.5719090699061228,
#  0.49220868215123903,
#  0.27417252796215996,
#  0.2419007974359515,
#  0.3180963221936799,
#  0.24254858925881762,
#  0.49329210212360197,
#  0.5697996862891204,
#  0.5463085301481644,
#  0.42055669023238484,
#  0.525283150769275,
#  0.41123623037655754,
#  0.5059967390281466,
#  0.5239523752943562,
#  0.485604693879398,
#  0.5126849874669299,
#  0.505870626596227,
#  0.5638833426052513,
#  0.4813304297368056,
#  0.7131765409353651,
#  0.5634644762777166,
#  0.5331841078663206,
#  0.32094983619016393,
#  0.6298212464059407,
#  0.51744152679455,
#  0.3794889257755214,
#  0.44351443210006014,
#  0.5518195620184099,
#  0.45492018892585895,
#  0.5106003151531309,
#  0.4700964564526793,
#  0.574644437996187,
#  0.6452731376575472,
#  0.5908427220742065,
#  0.5830269665939347,
#  0.5864984418456711,
#  0.6322463818602306,
#  0.5985622591087264,
#  0.5405985139420911,
#  0.6514706649774573,
#  0.38547406851076915,
#  0.567937260366594,
#  0.4499641718771791,
#  0.05297573365498687,
#  0.3395445244104881,
#  0.5241385897378369,
#  0.5950121218379966,
#  0.42260363682814517,
#  0.4658027646686975,
#  0.6091529486009974,
#  0.47748763715662257,
#  0.5138883168649311]

# %%
best_index = np.argmax(scores)
# print(scores[best_index])
print(f"{best_index} : {scores[best_index]}" )
# Out:
# 34 : 0.7232676944522258

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = best_index)
#Lets train pipe with best_index
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jeep', 'Mahindra', 'Maruti',
#        'Mercedes', 'Mitsubishi', 'Nissan', 'Renault', 'Skoda', 'Tata',
#        'Toyota', 'Volkswagen'], dtype=object)...
#        'i10 Magna 1.2', 'i10 Magna 1.2 Kappa2', 'i10 Sportz',
#        'i10 Sportz 1.2', 'i20', 'i20 Active', 'i20 Active 1.2 SX',
#        'i20 Active 1.4L SX O', 'i20 Asta', 'i20 Asta 1.2',
#        'i20 Asta 1.4 CRDI 6 Speed', 'i20 Magna', 'i20 Magna 1.2',
#        'i20 Magna O 1.2', 'i20 Select Variant', 'i20 Sportz 1.2',
#        'i20 Sportz 1.4 CRDI'], dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
import pickle

# Pipeline/Model save 
pickle.dump(pipe, open('model.pkl', 'wb'))

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
data = [['Ford', 'Figo', 2015, 70000, 'Petrol']]
columns = ['company', 'name', 'year', 'kms_driven', 'fuel_type']
myinput = pd.DataFrame(data = data, columns = columns)
result = pipe.predict(myinput)
print("Predicted price is:", round(result[0,0]))
# Out:
# Predicted price is: 283545
